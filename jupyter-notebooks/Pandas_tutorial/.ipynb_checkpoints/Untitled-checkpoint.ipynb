# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import numpy as np
from numpy import random 
# %matplotlib inline

# %%
nomes = ['Paulo', 'Fernanda', 'Julia', 'Joao', 'Diogo']

# %%
random.seed(500)
random_nomes = [nomes[random.randint(low=0,high=len(nomes))] for i in range(1000)]

random_nomes[:10]
# Out:
# ['Julia',
#  'Fernanda',
#  'Fernanda',
#  'Paulo',
#  'Fernanda',
#  'Fernanda',
#  'Fernanda',
#  'Julia',
#  'Julia',
#  'Julia']

# %%
births = [random.randint(low=0,high=1000) for i in range(1000)]
births[:10]
# Out:
# [968, 155, 77, 578, 973, 124, 155, 403, 199, 191]

# %%
bebes_dados = list(zip(random_nomes, births))
bebes_dados
# Out:
# [('Julia', 968),
#  ('Fernanda', 155),
#  ('Fernanda', 77),
#  ('Paulo', 578),
#  ('Fernanda', 973),
#  ('Fernanda', 124),
#  ('Fernanda', 155),
#  ('Julia', 403),
#  ('Julia', 199),
#  ('Julia', 191),
#  ('Joao', 769),
#  ('Paulo', 88),
#  ('Paulo', 43),
#  ('Julia', 393),
#  ('Julia', 164),
#  ('Joao', 45),
#  ('Diogo', 148),
#  ('Julia', 609),
#  ('Diogo', 134),
#  ('Joao', 726),
#  ('Joao', 106),
#  ('Diogo', 355),
#  ('Fernanda', 774),
#  ('Joao', 214),
#  ('Fernanda', 732),
#  ('Julia', 362),
#  ('Julia', 682),
#  ('Joao', 141),
#  ('Fernanda', 433),
#  ('Paulo', 892),
#  ('Joao', 328),
#  ('Fernanda', 151),
#  ('Fernanda', 737),
#  ('Joao', 200),
#  ('Paulo', 626),
#  ('Diogo', 679),
#  ('Fernanda', 812),
#  ('Diogo', 481),
#  ('Diogo', 723),
#  ('Julia', 98),
#  ('Fernanda', 76),
#  ('Diogo', 911),
#  ('Diogo', 948),
#  ('Diogo', 698),
#  ('Diogo', 539),
#  ('Paulo', 806),
#  ('Joao', 885),
#  ('Fernanda', 785),
#  ('Fernanda', 750),
#  ('Paulo', 233),
#  ('Joao', 442),
# ...

# %%
df1 = pd.DataFrame(data = bebes_dados, columns = ['Nomes', 'Nascimentos'])
df1[:10]
# Out:
#       Nomes  Nascimentos
# 0     Julia          968
# 1  Fernanda          155
# 2  Fernanda           77
# 3     Paulo          578
# 4  Fernanda          973
# 5  Fernanda          124
# 6  Fernanda          155
# 7     Julia          403
# 8     Julia          199
# 9     Julia          191

# %%
df.to_csv('nasci1880.txt', index = False, header = False)

# %%
location = r'C:\Users\Paulo\programacao\jupyter-notebooks\Pandas_tutorial\nasci1880.txt'
df2 = pd.read_csv(location, header = None)

# %%
df2.head()
# Out:
#           0    1
# 0     Julia  968
# 1  Fernanda  155
# 2  Fernanda   77
# 3     Paulo  578
# 4  Fernanda  973

# %%
df2.tail()
# Out:
#             0    1
# 995      Joao  151
# 996  Fernanda  511
# 997      Joao  756
# 998  Fernanda  294
# 999      Joao  152

# %%
df2 = read_csv(location, names = ['Nomes', 'Nascimentos'])
df2
# Out:
#         Nomes  Nascimentos
# 0       Julia          968
# 1    Fernanda          155
# 2    Fernanda           77
# 3       Paulo          578
# 4    Fernanda          973
# 5    Fernanda          124
# 6    Fernanda          155
# 7       Julia          403
# 8       Julia          199
# 9       Julia          191
# 10       Joao          769
# 11      Paulo           88
# 12      Paulo           43
# 13      Julia          393
# 14      Julia          164
# 15       Joao           45
# 16      Diogo          148
# 17      Julia          609
# 18      Diogo          134
# 19       Joao          726
# 20       Joao          106
# 21      Diogo          355
# 22   Fernanda          774
# 23       Joao          214
# 24   Fernanda          732
# 25      Julia          362
# 26      Julia          682
# 27       Joao          141
# 28   Fernanda          433
# 29      Paulo          892
# ..        ...          ...
# 970  Fernanda          572
# 971  Fernanda          639
# ...

# %%
df2['Nomes'].unique()
# Out:
# array(['Julia', 'Fernanda', 'Paulo', 'Joao', 'Diogo'], dtype=object)

# %%
for n in df2['Nomes'].unique():
    print(n)
# Out:
# Julia
# Fernanda
# Paulo
# Joao
# Diogo

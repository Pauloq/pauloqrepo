# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
#%matplotlib inline

# %%
local = r'C:\Users\Apaluz\programacao\pauloqrepo\dados_brutos\dadoscsv.csv'
df = pd.read_csv(local, names = ['Scan_Count', 'Julian Days', 'Descent Rate', 'Pressure', 'Temperature', 'Conductivity','Oxygen','Depth','Flag'])

# %%
df
# Out:
#        Scan_Count  Julian Days  Descent Rate  Pressure  Temperature  \
# 0               1   164.440475  8.182000e-16    -0.424      23.4711
# 1               2   164.440475  2.000000e-03    -0.421      23.4714
# 2               3   164.440476  2.000000e-03    -0.419      23.4717
# 3               4   164.440476  4.000000e-03    -0.417      23.4720
# 4               5   164.440476  3.000000e-03    -0.416      23.4723
# 5               6   164.440477  6.000000e-03    -0.414      23.4727
# 6               7   164.440477  8.000000e-03    -0.412      23.4730
# 7               8   164.440478  8.000000e-03    -0.412      23.4733
# 8               9   164.440478  7.000000e-03    -0.411      23.4736
# 9              10   164.440479  9.000000e-03    -0.408      23.4738
# 10             11   164.440479  1.100000e-02    -0.406      23.4741
# 11             12   164.440480  1.100000e-02    -0.404      23.4743
# 12             13   164.440480  1.600000e-02    -0.403      23.4745
# ...

# %%
plt.figure()
plt.plot(df.Temperature, df.Scan_Count, '-g')
plt.show()

# %%
df['Temperature'].plot()
plt.show()

# %%
Temperature = df.Temperature

# %%
Temperature[2]
# Out:
# 23.471699999999998

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-9ae93f22b889> in <module>()
# ----> 1 df[0]
#
# C:\Users\Apaluz\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# C:\Users\Apaluz\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Apaluz\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# ...
